# %% [markdown]
# <a href="https://colab.research.google.com/github/lammycrakudo69/arquivo-super-crakudo/blob/main/EU_ODEIO_A_ETEC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#estrutura de decisão

numero = 5


numero01 = int ( input ("digite um número"))

if numero > numero01 :
  print (f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2557/1656175600.py in <cell line: 0>()
#       4
#       5
# ----> 6 numero01 = int ( input ("digite um número"))
#       7
#       8 if numero > numero01 :
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
# escrever um programa que leia dois numeris e retorne se eles são iguais

a = int ( input ("digite um número"))
b = int ( input ("digite um número"))

# %%
# escrever um programa que leia as notas dos quatro bimestre e o nome do aluno calcule a media

#media menor que 5 -´reprovado

# medial menor que 7 - recuperação

#media maior que 7 - aprovado
