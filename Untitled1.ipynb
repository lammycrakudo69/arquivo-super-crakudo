# %% [markdown]
# <a href="https://colab.research.google.com/github/lammycrakudo69/arquivo-super-crakudo/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#entrada

comprimento = float (input("digite o comprimento: "))
altura = float (input ("digite a altura: "))

# processamento

area = comprimento * altura

#saída

print (f"o total de área do retangulo é igual: {area}")
# Out:
# digite o comprimento: 66
# digite a altura: 99
# o total de área do retangulo é igual: 6534.0

# %%
#escrever um programa qye soma dois números

#entrada

a = int (int("digite o primeiro número"))
b = int (int("digite o segundo número"))

# processamento

soma = a + b

print ("----------------calculadora simples--------------------")

print ("----------------soma-----------------------------------")

print ("----------------subtração------------------------------")


#saida

print (f"o resultado da soma de {a} mais {b} é igual : {soma}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_290/4023492130.py in <cell line: 0>()
#       3 #entrada
#       4
# ----> 5 a = int (int("digite o primeiro número"))
#       6 b = int (int("digite o segundo número"))
#       7
#
# ValueError: invalid literal for int() with base 10: 'digite o primeiro número'

# %% [markdown]
# escrever um programa que recebe a tempereratura em graus celcius e converter a  fahrenheit
#
# #entrada: graus celcius
#
# #prosessamento
