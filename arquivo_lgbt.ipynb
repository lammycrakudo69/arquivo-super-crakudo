# %% [markdown]
# <a href="https://colab.research.google.com/github/lammycrakudo69/arquivo-super-crakudo/blob/main/arquivo_lgbt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# entrada

comprimento= 7 #mertros
largura = 4 #metros

# %%
# processamento

area = comprimento * largura

# %%
print (f"área total da sala é: {area} metros quadrados")
# Out:
# área total da sala é: 28 metros quadrados

# %%
#entrada

lado = 2

#processamento

resultado = lado * lado

#saída

print (f"o resultado do quadrado é : {resultado}")
# Out:
# o resultado do quadrado é : 4

# %%
# entrada

comprimento= 12 #mertros
largura = 7 #metros

# %%
# processamento

area = comprimento * largura

# %%
print (f"área total da sala é: {area} metros quadrados")
# Out:
# área total da sala é: 84 metros quadrados

# %%
#entrada

mumero= 3

#procesamento
