# %% [markdown]
# <a href="https://colab.research.google.com/github/lammycrakudo69/arquivo-super-crakudo/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#entrada

par = int (input("digite um numero"))
impar = int (input("digite um numero"))

print ("opcao 1 = par ")
print ("opcao 2 = impar ")

opcao = int (input("digite a opcao desejada"))

if opcao == 1:
  print (f"{i}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9946/2870349696.py in <cell line: 0>()
#       1 #entrada
#       2
# ----> 3 par = int (input("digite um numero"))
#       4 impar = int (input("digite um numero"))
#       5
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
#entrada

a = int
# Out:
# 2
# 3

# %%
#entrada

a = int (input("digite um numero: "))
b = int (input("digite um numero: "))

opcao = int (input("digite a opção desejada" ))

print ("opção 1 = soma")
print ("opção 2 = subtracao")
print ("opção 3 = multiplicacao")
print ("opção 4 = divisao")

if opcao == 1:
 print (f"{a + b}")

elif opcao == 2:
 print (f"{a - b}")

elif opcao == 3:
 print (f"{a * b}")

elif opcao == 4:
 print (f"{a / b}")

else:

 print("digite uma opção válida")
# Out:
# digite um numero: 3
# digite um numero: 4
# digite a opção desejadasubtracao
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9946/3078476605.py in <cell line: 0>()
#       4 b = int (input("digite um numero: "))
#       5
# ----> 6 opcao = int (input("digite a opção desejada" ))
#       7
#       8 print ("opção 1 = soma")
#
# ValueError: invalid literal for int() with base 10: 'subtracao'

# %%
#entrada

a = int (input("digite um numero: "))

print ("opção 1 = domingo")
print ("opção 2 = segunda")
print ("opção 3 = terça")
print ("opção 4 = quarta")
print ("opção 5 = quinta")
print ("opção 6 = sexta")
print ("opção 7 = sabado")
